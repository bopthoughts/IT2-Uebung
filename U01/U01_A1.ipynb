# %% [markdown]
# # Übung Informationstechnik im Maschinenbau II
# ## U01 - Aufgabe 1: Vektorielles Kräftegleichgewicht

# %% [markdown]
# ## Aufgabenstellung
#
# Ein Punkt $P$ im 3-dimensionalen ($x,y,z$)-Koordintatensystem sei über drei Stäbe $S_1$, $S_2$, $S_2$ mit Lagern in $P_1$, $P_2$, $P_3$verbunden. Berechnen Sie die Stabkräfte für eine beliebige am Punkt $P$ angreifende Kraft $F$.

# %% [markdown]
# ### a) Symmetrischer Fall
# Die Punkte $P_1$, $P_2$, $P_3$ bilden zunächst ein gleichseitiges Dreieck mit der Seitenlänge $a=4$ bei $z=0$ Der Punkt $P$ liegt bei $z=5$ genau über dem Schwerpunkt des Dreiecks.
#
# ![anordnung_symm.png](attachment:de6f3520-e670-4909-934d-5fab775d744c.png)
#
# Teilaufgaben:
#
# 1. Berechnen Sie die Koordinaten der Punkte $P$, $P_1$, $P_2$, $P_3$
# 2. Geben Sie die Stäbe als Vektoren $\vec{s_n} = \overline{P_n P}$ an
# 3. Formulieren Sie die Kräftebilanz im Punkt $P$ als Vektorgleichung
# 4. Zerlegen Sie die vektoriellen Stabkräfte in Betrag und Richtung
# 5. Formulieren Sie das Gleichungssystem zur Berechnung der Beträge
# 5. Berechnen Sie die Stabkräfte für eine an $P$ angreifende Kraft $\vec{F}=\begin{bmatrix}0\\0\\-5\end{bmatrix}N$
# 6. Prüfen und interpretieren Sie die Lösung

# %% [markdown]
# ### 1. Berechnung der Koordinaten

# %%
import

# %%
a = 4
h = 

# Lagen der Punkte
P  =  
P1 = 
P2 = 
P3 = 

P, P1, P2, P3

# %% [markdown]
# ### 2. Stäbe als Vektoren

# %%
s1 = 
s2 = 
s3 = 

s1, s2, s3

# %%
# Prüfen auf Symmetrie (gleiche Längen der Stäbe)

# %% [markdown]
# ### 3. Schritt: Kräftebilanz als Vektorgleichung

# %% [markdown]
# ### 4. Schritt: Stabkräfte in Betrag und Richtung zerlegen

# %%
r1 = 
r2 = 
r3 = 

r1, r2, r3

# %% [markdown]
# ### 5. Schritt: Formulieren als Gleichungssystem in Matrix-Schreibweise

# %%
A =

# %% [markdown]
# Die rechte Seite der Gleichung ist die äußere Kraft $-\vec F$

# %%
F = 
y =

# %% [markdown]
# ### 6. Schritt: Lösen des Gleichungssystems
#
# Das Gleichungssystem muss nun nach dem Vektor der unbekannten Stabkräfte aufgelöst werden. Dies geschieht mit der Funktion `numpy.linalg.solve()`

# %%
x =

# %% [markdown]
# ### 7. Schritt: Prüfen und Interpretieren
#
# - Plausibilität:
# - Lösung rechnerisch nachprüfen:
# - "Mechanisch" nachprüfen:

# %%
# Rechnerisch

# %% [markdown]
# ob die Werte "klein genug" sind, um als Null zu gelten, prüfen wir mit `np.isclose()`

# %%
# Mechanisch

# %% [markdown]
# ### b) Asymmetrischer Fall
# Die Punkte $P_1$, $P_2$, $P_3$ und der Punkt $P$ liegen beliebig. Die äußere Last ist beliebig schief
#
# Wiederholen Sie alle Schritte
